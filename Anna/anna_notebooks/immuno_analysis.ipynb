# %% [markdown]
# <a href="https://colab.research.google.com/github/GergelyTuri/fiberphotometry/blob/annas/notebooks/pcb_experiments/anna_notebooks/immuno_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b annas https://github.com/GergelyTuri/fiberphotometry.git
# Out:
# Cloning into 'fiberphotometry'...
# remote: Enumerating objects: 426, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 426 (delta 95), reused 97 (delta 34), pack-reused 245
# Receiving objects: 100% (426/426), 27.68 MiB | 24.95 MiB/s, done.
# Resolving deltas: 100% (218/218), done.

# %%
# %cd fiberphotometry
# Out:
# /content/fiberphotometry

# %%
# !pip install .
# Out:
# Processing /content/fiberphotometry
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.0 MB/s eta 0:00:00
# ...
#   Created wheel for fiber-photometry-analysis: filename=fiber_photometry_analysis-0.1-py3-none-any.whl size=9360 sha256=224a9ccae3dce95ecff7a95c9f8174a883a5cad72f48ae2336b7270e90e745ac
#   Stored in directory: /tmp/pip-ephem-wheel-cache-b9mo5b3t/wheels/4b/b6/cf/916d1f43d06b8bc573d2ec7471e525018bf5ea7bcf83b8e670
# Successfully built fiber-photometry-analysis
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from Anna.immuno_analysis import load_and_merge_data
from Anna.immuno_plotting import plot_area
import numpy as np

# %%
def main():
    # Paths to the CSV files
    df1_path = '/gdrive/MyDrive/csvs/experimental_groups - Sheet1.csv'
    df2_path = '/gdrive/MyDrive/csvs/63x_BDNF_data - Sheet1.csv'

    # Load and merge the data
    merged_df = load_and_merge_data(df1_path, df2_path)

    # Print the merged DataFrame
    print("\nMerged DataFrame:")
    print(merged_df.head())

    # Plot for hilus
    plot_area(merged_df, 'hilus')

    # Plot for CA3
    plot_area(merged_df, 'CA3')

if __name__ == "__main__":
    main()
# Out:
# Merged DataFrame:
#   animal_ID  weight group_x sex injection date sac date  Sac weight  \
# 0   arc13a1    42.0     pcb   m       1/2/2024   1/9/24       43.83
# 1   arc13a1    42.0     pcb   m       1/2/2024   1/9/24       43.83
# 2   arc13a1    42.0     pcb   m       1/2/2024   1/9/24       43.83
# 3   arc13a1    42.0     pcb   m       1/2/2024   1/9/24       43.83
# 4   arc13a1    42.0     pcb   m       1/2/2024   1/9/24       43.83
#
#    sac-injection drug_condition drug_code  ... Unnamed: 8 Unnamed: 9  \
# 0              7           pcb7         a  ...        NaN        NaN
# 1              7           pcb7         a  ...        NaN        NaN
# 2              7           pcb7         a  ...        NaN        NaN
# 3              7           pcb7         a  ...        NaN        NaN
# 4              7           pcb7         a  ...        NaN        NaN
#
#   Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  volume  \
# ...
