# %% [markdown]
# <a href="https://colab.research.google.com/github/GergelyTuri/fiberphotometry/blob/main/notebooks/calcium_analysis_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Calcium analysis demo
#
# * 8/30/2023 setting up
# * 9/26/23 working on the fiberphot data class
# * 9/27/23 class seems to be working
# * 9/27/23 all running

# %%
# !git clone -b gergo_dfof_strategies https://github.com/GergelyTuri/fiberphotometry.git
# %cd fiberphotometry
# !pip install .
# Out:
# Cloning into 'fiberphotometry'...
# remote: Enumerating objects: 530, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 530 (delta 27), reused 30 (delta 13), pack-reused 476 (from 1)
# Receiving objects: 100% (530/530), 29.87 MiB | 9.32 MiB/s, done.
# Resolving deltas: 100% (289/289), done.
# Updating files: 100% (50/50), done.
# /content/fiberphotometry
# Processing /content/fiberphotometry
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.6 MB/s eta 0:00:00
# ...
#   Created wheel for fiber-photometry-analysis: filename=fiber_photometry_analysis-0.1-py3-none-any.whl size=9462 sha256=e736200db4a27f02499b7dfbda7c07448057e6bd1cbfadc4141d5fc017dbae51
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xxlkzd0p/wheels/4b/b6/cf/916d1f43d06b8bc573d2ec7471e525018bf5ea7bcf83b8e670
# Successfully built fiber-photometry-analysis
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /content/fiberphotometry/
# !git pull

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics

from fiberphotometry.src import fiberphotometry as fp
# %matplotlib inline

# %% [markdown]
# ## Loading some test data

# %%
tank_path='/gdrive/Shareddrives/Turi_lab/Data/fiber_photometry/test_recordings/1aflox22a_1-230819-160056/'
tdt_tank = fp.FiberPhotometry(tank_path)

ff  = fp.FiberPhotometryAnalysis(tdt_tank.tank_path)
# Out:
# Found Synapse note file: /gdrive/Shareddrives/Turi_lab/Data/fiber_photometry/test_recordings/1aflox22a_1-230819-160056/Notes.txt
# read from t=0s to t=365.35s
# Found Synapse note file: /gdrive/Shareddrives/Turi_lab/Data/fiber_photometry/test_recordings/1aflox22a_1-230819-160056/Notes.txt
# read from t=0s to t=365.35s

# %%
dfof = ff.calculate_deltaf_f()
dfof_tdt = ff.calculate_deltaf_f(strategy="tdt")
# Out:
# /content/fiberphotometry/src/fiberphotometry.py:158: RankWarning: Polyfit may be poorly conditioned
#   bls = np.polyfit(x, y, 1)

# %%
plt.figure(figsize=(15,3))
plt.plot(dfof[500:])

# %%
plt.figure(figsize=(15,3))
plt.plot(dfof_tdt[500:])
